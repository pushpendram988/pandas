# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpendram988/pandas/blob/new-code/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dic = {"symbol":[1,2,3,4],"Security":[4,5,6,7],"change":[0,2,3,4]}
var = pd.DataFrame(dic)
var
# Out:
#    symbol  Security  change
# 0       1         4       0
# 1       2         5       2
# 2       3         6       3
# 3       4         7       4

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=var)
# Out:
# https://docs.google.com/spreadsheets/d/1znsahDEtAYLjidtwGdAdC1cfFq-Gq-mAGlTmeUS-Z-I/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1znsahDEtAYLjidtwGdAdC1cfFq-Gq-mAGlTmeUS-Z-I/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
var = pd.read_csv("/content/A_new.csv")
var
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       NaN     2.0
# 2       3       6.0     3.0
# 3       4       7.0     NaN

# %%
from google.colab import files

print("Please upload the 'A_new.csv' file.")
uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
# Please upload the 'A_new.csv' file.
#      <input type="file" id="files-e799b2c1-6a1c-417b-a52f-ba6286d47ad9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e799b2c1-6a1c-417b-a52f-ba6286d47ad9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# After uploading the file, you can now modify the cell `cMr2Nm0bJGiB` to read the file from the Colab environment. The path will typically be `/content/A_new.csv`.

# %%
import pandas as pd
var4 = pd.read_csv("/content/A_new.csv")
var
# Out:
#    symbol  Security  change  total
# 0       1        12      12      0
# 1       1        23       1      1
# 2       2         4       0      1
# 3       3         1       0     23

# %%
var.dropna(axis=1)
# Out:
#    symbol
# 0       1
# 1       2
# 2       3
# 3       4

# %%
var.dropna(axis =1)
# Out:
#    symbol
# 0       1
# 1       2
# 2       3
# 3       4

# %%
var.dropna(subset=["change"])
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       NaN     2.0
# 2       3       6.0     3.0

# %%
var.dropna(inplace=True)
var
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var.dropna(thresh = 1)
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var.fillna("python")
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var.fillna({"symbol":"python","Security":"java","change":"js"})
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var.fillna(method="ffill")
# Out:
# /tmp/ipykernel_519/3062787689.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var.fillna(method="ffill")
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var.fillna(method="bfill")
# Out:
# /tmp/ipykernel_519/119153051.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var.fillna(method="bfill")
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var.fillna(method="bfill",axis=1)
# Out:
# /tmp/ipykernel_519/249782568.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var.fillna(method="bfill",axis=1)
#    symbol  Security  change
# 0     1.0       4.0     0.0
# 2     3.0       6.0     3.0

# %%
var.bfill(axis=1)
# Out:
#    symbol  Security  change
# 0     1.0       4.0     0.0
# 2     3.0       6.0     3.0

# %%
var.ffill(axis=1)
# Out:
#    symbol  Security  change
# 0     1.0       4.0     0.0
# 2     3.0       6.0     3.0

# %%
var.fillna(12,inplace=True)
var
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var
var.fillna("python",limit=2)
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
var.fillna("python",limit= 2)
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0

# %%
import pandas as pd

dic = {"symbol":[1,1,2,3],"Security":[12,23,4,1],"change":[12,1,0,0],"total":[0,1,1,23]}

var = pd.DataFrame(dic)
var
# Out:
#    symbol  Security  change  total
# 0       1        12      12      0
# 1       1        23       1      1
# 2       2         4       0      1
# 3       3         1       0     23

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=var)
# Out:
# https://docs.google.com/spreadsheets/d/1rK_1tuebfZstrSN99TFKLkFXrSf28RIooESXXEn7dUI/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1rK_1tuebfZstrSN99TFKLkFXrSf28RIooESXXEn7dUI/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
var1 = var.to_csv("new.csv")
var1

# %%
var1 = var.to_csv("new.csv",index=False)
var1
var
# Out:
#    symbol  Security  change  total
# 0       1        12      12      0
# 1       1        23       1      1
# 2       2         4       0      1
# 3       3         1       0     23

# %%
var1 = pd.read_csv("new.csv")
var1
# Out:
#    symbol  Security  change  total
# 0       1        12      12      0
# 1       1        23       1      1
# 2       2         4       0      1
# 3       3         1       0     23

# %%
var1
# Out:
#    symbol  Security  change  total
# 0       1        12      12      0
# 1       1        23       1      1
# 2       2         4       0      1
# 3       3         1       0     23

# %%
var1.replace(to_replace=1,value=22)
# Out:
#    symbol  Security  change  total
# 0      22        12      12      0
# 1      22        23      22     22
# 2       2         4       0     22
# 3       3        22       0     23

# %%
d= var1.replace(to_replace=0,value="python")
d
# Out:
#    symbol  Security  change   total
# 0       1        12      12  python
# 1       1        23       1       1
# 2       2         4  python       1
# 3       3         1  python      23

# %%
var1.replace([1,1,2,3],22)
# Out:
#    symbol  Security  change  total
# 0      22        12      12      0
# 1      22        23      22     22
# 2      22         4       0     22
# 3      22        22       0     23

# %%
d.replace("[A-Za-z]","java",regex=True)
# Out:
#    symbol  Security                    change                     total
# 0       1        12                        12  javajavajavajavajavajava
# 1       1        23                         1                         1
# 2       2         4  javajavajavajavajavajava                         1
# 3       3         1  javajavajavajavajavajava                        23

# %%
d.replace("[y]","js",regex =True)
# Out:
#    symbol  Security   change    total
# 0       1        12       12  pjsthon
# 1       1        23        1        1
# 2       2         4  pjsthon        1
# 3       3         1  pjsthon       23

# %%
d.replace({"symbol":'[a-z]'},22,regex=True)
# Out:
#    symbol  Security  change   total
# 0       1        12      12  python
# 1       1        23       1       1
# 2       2         4  python       1
# 3       3         1  python      23

# %%
d.replace(1,method="ffill")
# Out:
# /tmp/ipykernel_519/1788006687.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   d.replace(1,method="ffill")
#    symbol  Security  change   total
# 0       1        12      12  python
# 1       1        23      12  python
# 2       2         4  python  python
# 3       3         4  python      23

# %%
var1.replace(1,method="bfill")
# Out:
# /tmp/ipykernel_519/1684171772.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var1.replace(1,method="bfill")
#    symbol  Security  change  total
# 0       2        12      12      0
# 1       2        23       0     23
# 2       2         4       0     23
# 3       3         1       0     23

# %%
var1.replace(1,method="ffill",limit =2)
# Out:
# /tmp/ipykernel_519/3095862301.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var1.replace(1,method="ffill",limit =2)
#    symbol  Security  change  total
# 0       1        12      12      0
# 1       1        23      12      0
# 2       2         4       0      0
# 3       3         4       0     23

# %%
var1.replace(1,method="ffill",limit =2,inplace=True)
var1
# Out:
# /tmp/ipykernel_519/4129366040.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var1.replace(1,method="ffill",limit =2,inplace=True)
#    symbol  Security  change  total
# 0       1        12      12      0
# 1       1        23      12      0
# 2       2         4       0      0
# 3       3         4       0     23

# %%
var4
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       NaN     2.0
# 2       3       6.0     3.0
# 3       4       7.0     NaN

# %%
var4.interpolate()
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       5.0     2.0
# 2       3       6.0     3.0
# 3       4       7.0     3.0

# %%
var4.interpolate(method="akima")
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       5.0     2.0
# 2       3       6.0     3.0
# 3       4       7.0     NaN

# %%
var4.interpolate(limit_direction="forward",limit=1)
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       5.0     2.0
# 2       3       6.0     3.0
# 3       4       7.0     3.0

# %%
var4.interpolate(limit_direction="both",limit=1)
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       5.0     2.0
# 2       3       6.0     3.0
# 3       4       7.0     3.0

# %%
var4
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       NaN     2.0
# 2       3       6.0     3.0
# 3       4       7.0     NaN

# %%
var4.interpolate(limit_area="outside")
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       NaN     2.0
# 2       3       6.0     3.0
# 3       4       7.0     3.0

# %%
var4.interpolate(limit_area="inside")
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       5.0     2.0
# 2       3       6.0     3.0
# 3       4       7.0     NaN

# %%
var4.interpolate(limit_direction="both",limit=1,inplace=True)
var4
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       5.0     2.0
# 2       3       6.0     3.0
# 3       4       7.0     3.0

# %% [markdown]
# var4

# %%
var4
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       5.0     2.0
# 2       3       6.0     3.0
# 3       4       7.0     3.0
