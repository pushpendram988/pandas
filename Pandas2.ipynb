# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpendram988/pandas/blob/main/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dic = {"symbol":[1,2,3,4],"Security":[4,5,6,7],"change":[0,2,3,4]}
var = pd.DataFrame(dic)
var
# Out:
#    symbol  Security  change
# 0       1         4       0
# 1       2         5       2
# 2       3         6       3
# 3       4         7       4

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=var)
# Out:
# https://docs.google.com/spreadsheets/d/1Fn9zoTGtOJG2sT_fHOhRAzKh8xCsP-_wPkZv3z_bfx4/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1Fn9zoTGtOJG2sT_fHOhRAzKh8xCsP-_wPkZv3z_bfx4/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
var = pd.read_csv("/content/A_new.csv")
var
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       NaN     2.0
# 2       3       6.0     3.0
# 3       4       7.0     NaN

# %%
from google.colab import files

print("Please upload the 'A_new.csv' file.")
uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
# Please upload the 'A_new.csv' file.
#      <input type="file" id="files-280f1884-cce6-4658-9eb7-af4b5ceac67a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-280f1884-cce6-4658-9eb7-af4b5ceac67a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# After uploading the file, you can now modify the cell `cMr2Nm0bJGiB` to read the file from the Colab environment. The path will typically be `/content/A_new.csv`.

# %%
import pandas as pd
var = pd.read_csv("/content/A_new.csv")
var
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 1       2       NaN     2.0
# 2       3       6.0     3.0
# 3       4       7.0     NaN

# %%
var.dropna()
# Out:
#    symbol  Security  change
# 0       1       4.0     0.0
# 2       3       6.0     3.0
